# %% [markdown]
# ### For testing the CDS API

# %%
import cdsapi

dataset = "reanalysis-era5-single-levels"
request = {
    "product_type": ["reanalysis"],
    "variable": ["mean_sea_level_pressure"],
    "year": ["2024"],
    "month": ["01"],
    "day": ["01"],
    "time": [
        "00:00", "01:00", "02:00",
        "03:00", "04:00", "05:00",
        "06:00", "07:00", "08:00",
        "09:00", "10:00", "11:00",
        "12:00", "13:00", "14:00",
        "15:00", "16:00", "17:00",
        "18:00", "19:00", "20:00",
        "21:00", "22:00", "23:00"
    ],
    "data_format": "netcdf",
    "download_format": "zip",
    "area": [35, -100, 25, -75]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-03-28 23:07:47,281 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-03-28 23:07:47,283 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2025-03-28 23:07:48,518 INFO Request ID is 79ab0424-5c0c-4e91-89ac-eba1fab0b370
# 2025-03-28 23:07:49,201 INFO status has been updated to accepted
# 2025-03-28 23:07:55,366 INFO status has been updated to running
# 2025-03-28 23:08:05,025 INFO status has been updated to successful
# '502f40de340719f2c9454ea3a8c4fcca.zip'
